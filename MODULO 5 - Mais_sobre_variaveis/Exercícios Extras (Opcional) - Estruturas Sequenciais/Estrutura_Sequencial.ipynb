# %% [markdown]
# # Lista de Estrutura Sequencial

# %% [markdown]
# #### 1. Faça um Programa que mostre a mensagem (print) "Alo mundo" na tela.

# %%
print('Olá mundo!')

# %% [markdown]
# #### 2. Faça um Programa que peça um número (input) e então mostre a mensagem: "O número informado foi [número]."

# %%
numero = int(input('Digite um número'))

print(f'O número informado foi {numero}')

# %% [markdown]
# #### 3. Faça um Programa que peça dois números e imprima a soma.

# %%
num1 = int(input('Digite o primeiro número'))
num2 = int(input('Digite o segundo número'))

print(f'A soma dos números é igual a {num1 + num2}')

# %% [markdown]
# #### 4. Faça um Programa que peça as 4 notas bimestrais de um aluno e mostre a média de todas as notas.

# %%
nota1 = float(input('Nota 1º Bimestre'))
nota2 = float(input('Nota 2º Bimestre'))
nota3 = float(input('Nota 3º Bimestre'))
nota4 = float(input('Nota 4º Bimestre'))

nota_final = ((nota1+nota2+nota3+nota4) /4)

print(nota_final)
# Out:
# 7.0

# %% [markdown]
# #### 5. Faça um Programa que converta metros para centímetros. Você pode pedir o comprimento em metros para o usuário (input).

# %%
metro = float(input('Insira o comprimento em metros desejado'))
              
result = metro * 100

print(result)
# Out:
# 1120.0

# %% [markdown]
# #### 6. Faça um Programa que calcule a área de uma sala de um apartamento. Para isso, o seu programa precisa pedir a largura da sala, o comprimento da sala e imprimir a área em m² da sala.

# %%
largura = int(input('Digite a largura da sala'))
altura = int(input('Digite a altura da sala'))

area = largura * altura

print(f'O apartamento possui : {area} m²')
# Out:
# O apartamento possui : 40 m²

# %% [markdown]
# #### 7. Faça um Programa que pergunte quanto você ganha por hora e o número de horas trabalhadas no mês. Calcule e mostre o total do seu salário no referido mês.

# %%
vl_hora = float(input('Digite o valor hora'))
qt_hr = float(input('Digite a quantidade total de horas trabalhadas no mês'))

print(f'O salário final foi de RS:{vl_hora*qt_hr} no mês')
# Out:
# O salário final foi de RS:6400.0 no mês

# %% [markdown]
# #### 8. Vamos criar um conversor de temperatura. Faça um Programa que peça a temperatura em graus Fahrenheit, transforme e mostre a temperatura em graus Celsius.
# $C = \frac{5}{9}(F-32)$

# %%
fr = float(input('Digite a temperatura em Fahrenheit'))

c =( (5/9)*(fr-32))

print(f'A temperatura é: {c} °C')
# Out:
# A temperatura é: 0.8333333333333334 °C

# %% [markdown]
# #### 9. Faça um Programa que peça a temperatura em graus Celsius, transforme e mostre em graus Fahrenheit.
# $F = \frac{9}{5}C + 32$

# %%
c = float(input('Digite a temperatura em Celsius'))

fr = ((9/5) * (c+32))

print(f'A temperatura é: {fr} ºF')
# Out:
# A temperatura é: 117.9 ºF

# %% [markdown]
# #### 10. Tendo como dados de entrada a altura (h) de uma pessoa, construa um algoritmo que calcule seu peso ideal, usando a seguinte fórmula:
# $P = 72,7h - 58$
#
# Lembrando que "algoritmo" nada mais é do que um programa, como todos os outros que você vem fazendo

# %%
h = float(input('Digite sua altura em metros'))

p = 72.7 *h -58

print(f'Com base na altura digitada seu peso ideal é {p} kg')
# Out:
# Com base na altura digitada seu peso ideal é 74.31400000000002 kg

# %% [markdown]
# #### 11. Tendo como dado de entrada a altura (h) de uma pessoa, construa um algoritmo que calcule seu peso ideal, utilizando as seguintes fórmulas:
# ##### a. Para homens: $P = 72,7h - 58$
# ##### b. Para mulheres: $P = 62,1h - 44,7$

# %%
h = float(input('Digite sua altura em metros'))

pa = 72.7 *h -58

pm = 62.1 *h -44.7

print(f'Com base na altura digitada seu peso ideal é {pa} kg, caso seja homem e de {pm} se for mulher')
# Out:
# Com base na altura digitada seu peso ideal é 72.86000000000001 kg, caso seja homem e de 67.08 se for mulher

# %% [markdown]
# #### 12. Faça um Programa que pergunte quanto você ganha por hora e o número de horas trabalhadas no mês.

# %%
vl_hora = float(input('Digite o valor recebido por hora'))
qt_hora = int(input('Digite a quantidade de horas trabalhadas no mês'))

# %% [markdown]
# #####  Calcule o salário bruto (horas * salario por hora)

# %%
sl_bruto = qt_hora * vl_hora

print(f'O seu salário bruto é de {sl_bruto}')
# Out:
# O seu salário bruto é de 10000.0

# %% [markdown]
# ##### Calcule o desconto do IR (11% do salário bruto)

# %%
ir = (sl_bruto * 11)/100

print(f'O Valor de descontado de imposto de Renda foi de {ir}')
# Out:
# O Valor de descontado de imposto de Renda foi de 1100.0

# %% [markdown]
# ##### Calcule o desconto do INSS (8% do salário bruto)

# %%
inss = (sl_bruto*8) /100

print(f'O valor descontado de INSS foide {inss}')
# Out:
# O valor descontado de INSS foide 800.0

# %% [markdown]
# ##### Calcule o desconto do sindicato (5% do salário bruto)

# %%
vl_sind = (sl_bruto*5)/100

print(f'O valor da contribuição sindical é de {vl_sind}')
# Out:
# O valor da contribuição sindical é de 500.0

# %% [markdown]
# ##### Calcule o salário líquido (salário bruto - descontos)

# %%
desconto = (ir+inss+vl_sind)

print(f'O valor do salário líquido é de {sl_bruto - desconto}')
# Out:
# O valor do salário líquido é de 7600.0

# %% [markdown]
# #### 13. Faça um programa para uma loja de tintas. O programa deverá pedir o tamanho em metros quadrados da área a ser pintada. Considere que a cobertura da tinta é de 1 litro para cada 3 metros quadrados e que a tinta é vendida em latas de 18 litros, que custam R\$ 80,00. Informe ao usuário a quantidades de latas de tinta a serem compradas e o preço total. (para simplificação nesse momento, não se preocupe em arredondar a quantidade de latas a serem compradas - vamos trabalhar isso em breve)

# %%
area = int(input('Digite a quantidade de M² a ser pintado'))

litros_tinta = area / 3 
latas = litros_tinta / 18
preco = latas * 80

print(f'Conforme a área informada serão gastos um total de {latas} latas dando um total de R$: {preco}')
# Out:
# Conforme a área informada serão gastos um total de 5.9259259259259265 latas dando um total de R$: 474.07407407407413

# %% [markdown]
# #### 14. Faça um programa que peça o tamanho de um arquivo para download (em MB) e a velocidade de um link de Internet (em Mbps), calcule e informe o tempo aproximado de download do arquivo usando este link (em minutos).
#
# Detalhe: MB significa megabyte, Mb (com b minúsculo) significa megabit. Um megabit é 1/8 de um megabyte.

# %%
tamanho = float(input('Digite o tamanho do arquivo desejado'))
velocidade = float(input('Digite a velocidade da internet'))

conversor = tamanho * 8

tempo = conversor / velocidade

tempo_minutos = tempo / 60

tempo_total_horas = tempo_minutos / 60

print(f'O tempo total para download será de {tempo_minutos} minutos equivalente a {tempo_total_horas} horas')
# Out:
# O tempo total para download será de 0.2730666666666667 minutos equivalente a 0.004551111111111112 horas
